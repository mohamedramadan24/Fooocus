# %%
from google.colab import drive
drive.mount('/content/drive')

# Define the target path in Google Drive
FOOCUS_DIR = '/content/drive/MyDrive/Fooocus'

# !pip install pygit2==1.15.1
# %cd /content

import os

# Check if Fooocus directory already exists in Drive
if not os.path.exists(FOOCUS_DIR):
  # Clone the repository into the specified Google Drive path
  # !git clone https://github.com/lllyasviel/Fooocus.git {FOOCUS_DIR}

# Navigate into the Fooocus directory in Drive
# %cd {FOOCUS_DIR}

# !python entry_with_update.py --share --always-high-vram
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 74.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.0
#     Uninstalling pygit2-1.19.0:
#       Successfully uninstalled pygit2-1.19.0
# ...
# /content
# Cloning into '/content/drive/MyDrive/Fooocus'...
# remote: Enumerating objects: 6730, done.
# remote: Total 6730 (delta 0), reused 0 (delta 0), pack-reused 6730 (from 1)
# Receiving objects: 100% (6730/6730), 33.35 MiB | 17.41 MiB/s, done.
# Resolving deltas: 100% (3847/3847), done.
# Updating files: 100% (612/612), done.
# /content/drive/MyDrive/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# /content/drive/MyDrive/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# ...
